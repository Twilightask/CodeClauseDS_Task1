# %%
# Data manipulation and analysis
import numpy as np
import pandas as pd

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick

# Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('telecom_churn_data.csv')

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
df.sample()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5187  2080-CAZNM  Female              1      No         No      41
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 5187          Yes           Yes     Fiber optic             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 5187              Yes          No         Yes             Yes  Month-to-month
#
#      PaperlessBilling     PaymentMethod MonthlyCharges  TotalCharges Churn
# 5187              Yes  Electronic check          104.4       4133.95    No
#
# [1 rows x 21 columns]

# %%
# Converting Total Charges to numerical data type.
df.TotalCharges = pd.to_numeric(df.TotalCharges, errors='coerce')

# %%
# Null values
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
meanval= np.mean(df['TotalCharges'])
meanval
# Out:
# 2283.3004408418656

# %%
df['TotalCharges'].fillna(value=meanval, inplace=True)
print(df['TotalCharges'])
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
df2 = df.iloc[:,1:]
#Convertin the predictor variable in a binary numeric variable
df2['Churn'].replace(to_replace='Yes', value=1, inplace=True)
df2['Churn'].replace(to_replace='No',  value=0, inplace=True)

# %%
#convert all the categorical variables into dummy variables
df_dummies = pd.get_dummies(df2)
df_dummies.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0       1           29.85         29.85      0           True
# 1              0      34           56.95       1889.50      0          False
# 2              0       2           53.85        108.15      1          False
# 3              0      45           42.30       1840.75      0          False
# 4              0       2           70.70        151.65      1           True
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# 0        False       False         True           True  ...
# 1         True        True        False           True  ...
# 2         True        True        False           True  ...
# 3         True        True        False           True  ...
# 4        False        True        False           True  ...
#
#    StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 0                False                     True              False
# ...

# %%
# Setting a more aesthetic Seaborn style
sns.set(style="whitegrid")

# Defining a color palette that contrasts well and looks more vibrant
colors = ['#FF6347', '#708090']  # Tomato Red and Slate Grey

# Plot gender distribution as a bar chart
ax = (df['gender'].value_counts()*100.0 / len(df)).plot(kind='bar', stacked=True, rot=0, color=colors, figsize=(8, 6))

# Format y-axis to show percentage
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylabel('% Customers', fontsize=14)
ax.set_xlabel('Gender', fontsize=14)
ax.set_title('Gender Distribution of Customers', fontsize=16, fontweight='bold')

# Add gridlines for easier reading
ax.grid(True, axis='y', linestyle='--', alpha=0.7)

# Remove the top and right spines for a cleaner look
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Create a list to collect the plt.patches data
totals = []

# Find the values and append to the list
for i in ax.patches:
    totals.append(i.get_height())

# Set individual bar labels using the above list
total = sum(totals)

for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    percentage = round((i.get_height()/total)*100, 1)
    ax.text(i.get_x() + i.get_width() / 2, i.get_height() - 3.5, 
            f'{percentage}%', ha='center', fontsize=12, color='white', fontweight='bold')

# Add annotations to indicate the total count
for patch in ax.patches:
    height = patch.get_height()
    ax.text(patch.get_x() + patch.get_width() / 2., height + 0.5,
            f'{int(height)}', ha="center", fontsize=10, color='black', fontweight='bold')

# Improve layout for better appearance
plt.tight_layout()

# Shows the final plot
plt.show()

# %%
ax = (df['SeniorCitizen'].value_counts()*100.0 /len(df))\
.plot.pie(autopct='%.1f%%', labels = ['No', 'Yes'],figsize =(5,5), fontsize = 12 )                                                                           
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylabel('Senior Citizens',fontsize = 12)
ax.set_title('Percentage of Senior Citizens', fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Percentage of Senior Citizens')

# %%
# Set a modern, aesthetic style
sns.set(style="whitegrid")

# Create subplots with 3 columns and shared y-axis
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(20, 6))

# Define new, vibrant color palette
colors = ['#FFA07A', '#5F9EA0', '#4682B4']  # Light Salmon, Cadet Blue, Steel Blue

# Plot for 'Month-to-Month Contract'
sns.histplot(df[df['Contract'] == 'Month-to-month']['tenure'], 
             bins=int(180/5), color=colors[0], edgecolor='black', ax=ax1)
ax1.set_ylabel('# of Customers', fontsize=14)
ax1.set_xlabel('Tenure (months)', fontsize=12)
ax1.set_title('Month-to-Month Contract', fontsize=16, fontweight='bold')

# Plot for 'One Year Contract'
sns.histplot(df[df['Contract'] == 'One year']['tenure'], 
             bins=int(180/5), color=colors[1], edgecolor='black', ax=ax2)
ax2.set_xlabel('Tenure (months)', fontsize=12)
ax2.set_title('One Year Contract', fontsize=16, fontweight='bold')

# Plot for 'Two Year Contract'
sns.histplot(df[df['Contract'] == 'Two year']['tenure'], 
             bins=int(180/5), color=colors[2], edgecolor='black', ax=ax3)
ax3.set_xlabel('Tenure (months)', fontsize=12)
ax3.set_title('Two Year Contract', fontsize=16, fontweight='bold')

# Improve the overall appearance
plt.tight_layout()

# Show the final plot
plt.show()

# %%
# Set the seaborn style for a more aesthetic look
sns.set(style="whitegrid")

# Define the services to plot
services = ['PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
            'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']

# Create subplots: 3 rows and 3 columns
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(18, 14))

# Define a color palette for consistency across all plots
colors = sns.color_palette("Set2")

# Loop through each service and plot bar charts in corresponding axes
for i, item in enumerate(services):
    row = i // 3  # Determine the row index
    col = i % 3   # Determine the column index
    
    # Plot the value counts for each service, assign axis and color
    ax = df[item].value_counts().plot(kind='bar', ax=axes[row, col], rot=0, color=colors)
    
    # Customize the title
    ax.set_title(item, fontsize=14, fontweight='bold')
    
    # Set axis labels
    ax.set_xlabel('Subscription Status', fontsize=12)
    ax.set_ylabel('Customer Count', fontsize=12)
    
    # Add gridlines for better readability
    ax.grid(True, axis='y', linestyle='--', alpha=0.7)
    
    # Remove top and right spines for a cleaner look
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

# Adjust layout to avoid overlap and improve spacing
plt.tight_layout()

# Display the plot
plt.show()

# %%
sns.boxplot(x = df.Churn, y = df.tenure)
# Out:
# <Axes: xlabel='Churn', ylabel='tenure'>

# %%
# Define a consistent style using seaborn and set a color palette
sns.set(style="whitegrid")

# Define custom color palette for the bars (keeping your 'black' and 'purple' choice)
colors = ['#2C2C2C', '#6A0DAD']  # Dark Gray and Deep Purple

# Group data by 'Contract' and 'Churn', calculate the size and plot stacked bar chart
contract_churn = df.groupby(['Contract', 'Churn']).size().unstack()

# Plot the bar chart (normalized to show % of customers)
ax = (contract_churn.T * 100.0 / contract_churn.T.sum()).T.plot(kind='bar',
                                                                width=0.5,
                                                                stacked=True,
                                                                rot=0,
                                                                figsize=(12, 7),
                                                                color=colors)

# Set y-axis formatter to show percentage values
ax.yaxis.set_major_formatter(mtick.PercentFormatter())

# Set legend properties for better readability
ax.legend(loc='upper right', prop={'size': 12}, title='Churn', title_fontsize='14')

# Label the axes and set the title
ax.set_ylabel('Customer percentage', size=14, labelpad=10)
ax.set_xlabel('Contract Type', size=14, labelpad=10)
ax.set_title('Churn by Contract Type', size=16, fontweight='bold', pad=15)

# Add data labels to the bars
for p in ax.patches:
    height = p.get_height()  # Height is the value
    if height > 0:  # Only add labels to non-zero bars
        ax.annotate(f'{height:.0f}%', 
                    (p.get_x() + p.get_width() / 2., p.get_y() + height / 2.), 
                    ha='center', va='center', color='white', weight='bold', size=12)

# Adjust the layout to ensure all elements fit well
plt.tight_layout()

# Show the final plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick

# Define a new color palette for a cleaner, modern look
colors = ['#34495E', '#8E44AD']  # Navy Blue and Vibrant Purple

# Group data by 'SeniorCitizen' and 'Churn', and calculate percentages
seniority_churn = df.groupby(['SeniorCitizen', 'Churn']).size().unstack()

# Create a stacked bar chart (normalized to show percentage)
ax = (seniority_churn.T * 100.0 / seniority_churn.T.sum()).T.plot(kind='bar',
                                                                  width=0.4,
                                                                  stacked=True,
                                                                  rot=0, 
                                                                  figsize=(10,6),
                                                                  color=colors)

# Set percentage format for the y-axis
ax.yaxis.set_major_formatter(mtick.PercentFormatter())

# Set legend properties for better readability
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), prop={'size':12}, title='Churn', title_fontsize='14')

# Label the axes and add a title
ax.set_ylabel('% Customers', size=14, labelpad=10)
ax.set_xlabel('Seniority Level (0 = Non-Senior, 1 = Senior)', size=14, labelpad=10)
ax.set_title('Churn by Seniority Level', size=16, fontweight='bold', pad=15)

# Add data labels to the bars
for p in ax.patches:
    height = p.get_height()
    if height > 0:  # Only add labels to non-zero bars
        ax.annotate(f'{height:.0f}%', 
                    (p.get_x() + p.get_width() / 2., p.get_y() + height / 2.), 
                    ha='center', va='center', color='white', weight='bold', size=12)

# Adjust layout to ensure everything fits well
plt.tight_layout()

# Show the final plot
plt.show()

# %%
# Create a KDE plot with bright colors
ax = sns.kdeplot(df.MonthlyCharges[(df["Churn"] == 'No')],
                 color="#FF6F61",  # Bright orange
                 shade=True)

ax = sns.kdeplot(df.MonthlyCharges[(df["Churn"] == 'Yes')],
                 ax=ax, 
                 color="#00C9A7",  # Bright cyan
                 shade=True)

# Update the legend and its position
ax.legend(["Not Churn", "Churn"], loc='upper right', fontsize=12)

# Set axis labels and title with larger fonts and padding
ax.set_ylabel('Density', fontsize=14, labelpad=10)
ax.set_xlabel('Monthly Charges', fontsize=14, labelpad=10)
ax.set_title('Distribution of Monthly Charges by Churn', fontsize=16, fontweight='bold', pad=15)

# Add grid for better readability
ax.grid(True, linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Creating a KDE plot with bright colors for TotalCharges
ax = sns.kdeplot(df.TotalCharges[(df["Churn"] == 'No')],
                 color="#FF6F61",  # Bright orange for "Not Churn"
                 shade=True)

ax = sns.kdeplot(df.TotalCharges[(df["Churn"] == 'Yes')],
                 ax=ax, 
                 color="#00C9A7",  # Bright cyan for "Churn"
                 shade=True)

# Update the legend and its position
ax.legend(["Not Churn", "Churn"], loc='upper right', fontsize=12)

# Set axis labels and title with larger fonts and padding
ax.set_ylabel('Density', fontsize=14, labelpad=10)
ax.set_xlabel('Total Charges', fontsize=14, labelpad=10)
ax.set_title('Distribution of Total Charges by Churn', fontsize=16, fontweight='bold', pad=15)

# Add grid for better readability
ax.grid(True, linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
plt.show()

# %%
y = df_dummies['Churn'].values
X = df_dummies.drop(columns = ['Churn'])

# Scaling all the variables to a range of 0 to 1
from sklearn.preprocessing import MinMaxScaler
features = X.columns.values
scaler = MinMaxScaler(feature_range = (0,1))
scaler.fit(X)
X = pd.DataFrame(scaler.transform(X))
X.columns = features

# %%
# Create Train & Test Data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
# Running logistic regression model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
result = model.fit(X_train, y_train)

# %%
from sklearn import metrics
prediction_test = model.predict(X_test)
# Print the prediction accuracy
print (metrics.accuracy_score(y_test, prediction_test))
# Out:
# 0.8059630856601988
